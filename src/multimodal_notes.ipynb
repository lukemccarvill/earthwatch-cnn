# %% [markdown]
# Attempting a new model that utilises both the images (like the CNN.ipyb) and the metadata (like MLP.ipynb) to improve classification accuracy.
# Luke, 29 June 2026.
#
# The rest of this text is autofill content (I got curious what it would say):
# --
# The idea is to combine the strengths of Convolutional Neural Networks (CNNs) for image feature extraction with Multi-Layer Perceptrons (MLPs) for handling structured metadata.To implement a model that combines CNNs for image processing and MLPs for metadata, we can follow these steps:
# 1. **Data Preparation**:
#    - Load and preprocess the image data (e.g., resizing, normalization).
#    - Load and preprocess the metadata (e.g., encoding categorical variables, scaling numerical features).
#    - Split the dataset into training, validation, and test sets.
# 2. **Model Architecture**:
#    - Define a CNN architecture for image feature extraction. This could include convolutional layers, pooling, and fully connected layers.
#    - Define an MLP architecture for processing the metadata. This could include input layers, hidden layers, and output layers.
#    - Combine the outputs of the CNN and MLP by concatenating their feature representations.
# 3. **Model Training**:
#     - Compile the combined model with an appropriate loss function and optimizer.
#     - Train the model on the training set while monitoring performance on the validation set.
#     - Implement early stopping or model checkpointing to prevent overfitting.
# 4. **Model Evaluation**:
#     - Evaluate the model on the test set to assess its classification accuracy.
#     - Analyze the results and compare them with baseline models (CNN only and MLP only).
# 5. **Hyperparameter Tuning**:
#    - Experiment with different hyperparameters such as learning rate, batch size, number of layers, and number of neurons in each layer to optimize performance.
# 6. **Deployment**:
#    - Save the trained model for future inference.
#    - Create a pipeline for preprocessing new data (both images and metadata) before feeding it into the model for predictions.
#    - Deploy the model in a production environment, ensuring it can handle incoming requests efficiently.
# 7. **Monitoring and Maintenance**:
#    - Continuously monitor the model's performance in production to detect any degradation over time.
